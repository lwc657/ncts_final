# %% [markdown]
# # 城市用水預測

# %% [markdown]
# ## 組員
# 廖偉欽、韓哈斯

# %% [markdown]
# ## 介紹
# 水資源是國家追求永續發展的項目之一，也是永續發展的重要關鍵要素。近年來在極端氣候下，水資源的取得環境越來越嚴峻，更顯其珍貴。在有限的水資源下，了解未來需求的變化即為重要課題。
# 對於自來水事業而言，售水量的預測與其營運息息相關，也是未來供水規劃的基礎。

# %% [markdown]
# ## 實作方法
# 本專案使用包含Feed Forward Neural Network 、 LSTM 、xgboost、random forest、lasso regression、 ridge regression等機器學習演算法及arima、sarima等time series 演算法作為自來水事業售水量預測方法。

# %% [markdown]
# ## 專案說明
# 以機器學習演算法進行售水量預測，為使方法在實務上簡單易用，僅需過去售水量和供水量資料即可使用，以過去1, 2, 3,…, 12個月的售水量及過去1, 2, 3,…, 12個月的供水量以及當下人口數共25個特徵X，次月的售水量為y。
# 本專案資料為基隆市售水量。
# 蒐集2006年至2018年基隆市的月售水量及供水量資料，用以預測之後的售水量。
# 資料讀入後，先進行正規化，使用Z-score normalization對X及y進行正規化，則可得到平均為0，標準差為1的資料。本專案為有時間序的預測，計算平均值和標準差時，由於實際作業時只能就所擁有資料計算，為符合此實際情形，本專案計算平均值及標準差僅使用訓練集資料，計算後再以此值對全資料集做正規化。
# 資料劃分至各集的方式常用的選擇是隨機選取，不過售水量預測問題屬於時間序列，較符合使用情境的方式應該是取某個時間點以前的資料做為訓練集，此時間點以後的資料作為測試集，才能模擬真實會遇到的狀況。最後以MAPE (mean absolute percentage error)，即預測值與實際值差之絕對值除以實際值，計算其平均誤差百分比以評估其結果，越低代表預測越準確。
#
# 每個演算法會有經過特徵選取3個最重要的特徵再預測，以及不經過特徵選取的結果，在選擇MAPE較低結果作為最終結果。

# %% [markdown]
# ## 結果
#
# 將所有模型繪圖，可以發現MAPE都在3%以下，顯示出其不錯的預測能力。
#
# ![Alt text](Figure_10.png)
#
# ![Alt text](Figure_14.png)
#
# ![Alt text](https://docs.google.com/spreadsheets/d/e/2PACX-1vSJnZR_JASKUy0E0R41RVEntGA46ELikzoFmqioJzHC6lfxtTrGUcp0Q1jidoW_ycW1pUGGNYPMdS3q/pubchart?oid=536001334&format=image)

# %% [markdown]
# ## 結語
# 綜合而言，對於時間性的資料預測，包含深度學習在內的各種機器學習模型雖然各有不同，普遍來說會以充分運用資料，並儘量抑制over fitting的發生。而在本專案中多以此特性發揮良好的預測效果，部分演算法在經特徵選取之後能得到更好的結果，部份則可能會降低準確度。
# 為使實務上容易使用，本專案針對僅需使用12個月內的售水量和供水量及人口做為預測變數。若欲將準確度再提升，可增加其他自然及社會環境的考量如氣候、用水習慣、經濟發展狀況等變數，惟在資料量不增加時，變數的增加可能會造成over fitting的發生，於變數的選擇上必須留意。
# 售水量的預測對自來水事業實務上重要的課題，也是未來供水規劃的基礎。本專案為月售水量的預測，屬於短期預測，針對重點為系統操作、供水管理、最佳化供水的決策問題。例如想讓供水系統操作最佳化，如果能有相對準確的預測用水量，則能較準確地達到所要目標。例如想讓供水系統操作最佳化，如果能有相對準確的預測用水量，則能較準確地達到所要目標。

# %% [markdown]
# ## 程式碼

# %%
#%% packages

# -*- coding: utf-8 -*-

import matplotlib.pyplot as plt
#import matplotlib.dates as md
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso, LassoCV, LassoLarsCV, LassoLarsIC
from sklearn.linear_model import RidgeCV
from sklearn.ensemble import RandomForestRegressor
import xgboost
import datetime as dt
import statsmodels.api as sm
import itertools
plt.style.use('seaborn-white')
from statsmodels.tsa.arima_model import ARIMA
from tensorflow.keras.layers import Dense
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
print(tf.__version__)
print(keras.__version__)

np.random.seed(1337)
PYTHONHASHSEED = 0
tf.random.set_random_seed(1337)
tf.set_random_seed(1337)

featSelect = 0

#%% load data
finalDataDf = pd.read_csv('data/MyData12.csv')
finalData = finalDataDf.values
X = finalData[:,:-1]
y = finalData[:,-1]


#%% feature normalization  and preprocess
testRate = 0.2
numTrain = int(len(X) * (1-testRate))
numTest = 1

m = X[:numTrain].mean(axis=0)
s = X[:numTrain].std(axis=0)

X = ( X - m ) / s
X[:,0:2] = 0
realX = X
#X_train = ( X_train - m ) / s
#X_test = ( X_test - m ) / s

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = testRate, shuffle = False)

numTest = len(y_test)
#numTrain = 1 - numTest

vec_date = np.vectorize(dt.date)

t = vec_date(finalData[:,0], finalData[:,1], 1)
#t_test = vec_date(X_test[:, 0], X_test[:, 1], 1)
t_test = vec_date(finalData[numTrain:, 0], finalData[numTrain:, 1], 1)
allFig = plt.figure()
allFigax = allFig.add_subplot(111)
allFigax.plot_date(t, y, '-', label='actual')
allFigax.legend(loc='upper right')
allFigax.set_xlabel("time")
allFigax.set_ylabel('volume(m3)')



#%% feature selection

lassoIC = LassoLarsIC()
lassoIC.fit(X_train, y_train)
coef = lassoIC.coef_
X = X[:,coef!=0]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = False)

coef = np.append(coef,0)
print(finalDataDf.columns[coef!=0])

#di = {'feature':finalDataDf.columns[coef!=0], 'coef':coef[coef!=0]}
#selectedFeature = pd.DataFrame(data=di)

selectedFeature = pd.DataFrame(data=coef[coef!=0], index=finalDataDf.columns[coef!=0], columns=['coef'])
selectedFeature.sort_values(by=['coef'],ascending=0).to_csv("featureCoef.csv")




#%% time series

realY = y

y = pd.DataFrame(y_train)
y.index = pd.DatetimeIndex(t[:numTrain])
decomposition = sm.tsa.seasonal_decompose(y[0], model='additive')

fig = decomposition.plot()
plt.xlabel("time")


p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

Param = []
Param_seasonal = []
AIC = []

#%% SARIMAX
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            Param.append(param)
            Param_seasonal.append(param_seasonal)
            AIC.append(results.aic)
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
        
minAIC = AIC.index(min(AIC))

mod = sm.tsa.statespace.SARIMAX(y,
                                order=Param[minAIC],
                                seasonal_order=Param_seasonal[minAIC],
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])

results.plot_diagnostics(figsize=(16, 8))
plt.show()

pred_uc = results.get_forecast(steps=numTest)
pred_ci = pred_uc.conf_int()
#ax = yttrain.plot(label='observed', figsize=(14, 7))
ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
plt.legend()
plt.show()

predictions = pred_uc.predicted_mean.values

#mse = ((predictions - y_test) ** 2).mean()
np.mean(abs(predictions - y_test)/y_test)
#
#print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))




#%% ARIMA   
Param = []

AIC = []     
for param in pdq:
    
    try:
        
        mod = ARIMA(y, order=param)
        results = mod.fit()
        Param.append(param)
        
        AIC.append(results.aic)
        print('ARIMA{} - AIC:{}'.format(param, results.aic))
    except:
        continue

minAIC = AIC.index(min(AIC))

mod = ARIMA(y,order=Param[minAIC])
results = mod.fit()
print(results.summary().tables[1])    

predictions = results.forecast(steps=numTest)[0]
#predictions = results.predict(start=dt.datetime(X_test[0,0], X_test[0,1], 1),
#                end=dt.datetime(X_test[-1,0], X_test[-1,1], 1))
np.mean(abs(predictions - y_test)/y_test)

#%% test plot

fig = plt.figure()
ax = fig.add_subplot(211)
plt.plot_date(t_test, y_test,'-', label='actual')
plt.legend(loc='upper right')

plt.ylabel('water supply(t)')
plt.title('Water Supply Prediction')

predAll = []

ax2 = fig.add_subplot(212)
plt.plot_date(t_test, y_test-y_test,'-', label='actual')
plt.grid(axis="y")
plt.ylabel('error(t)')
plt.xlabel('time')

def draw_prediction(predictions, y_test, mName):
    
    res = predictions - y_test
    ax.plot_date(t_test, predictions,'-', label=mName)
    ax.legend(loc='best')
    ax2.plot_date(t_test, res, '-', label=mName)
    ax2.legend(loc='best')
    
    allFigax.plot_date(t_test, predictions,'-', label=mName)
    allFigax.legend(loc='best')
    # np.mean(abs(y_train_pred - y_train))/np.mean(y_train)
    print(np.mean(abs(res/y_test)))
    # print(np.mean(abs(res))/np.mean(y_test))




#%% y normalization

mY = y_train.mean()
sY = y_train.std()
y_train = ( y_train - mY ) / sY
# y_test = ( y_test - mY ) / sY



#%% lasso regression
"""
lassocv.alplha_ is different from which in R
"""

mName = 'lasso'
lassocv = LassoLarsIC()
lassocv.fit(X_train, y_train)
y_train_pred = lassocv.predict(X_train)
predictions = lassocv.predict(X_test)
predictions = predictions * sY + mY
#predAll = np.append(predAll,predictions).reshape([-1,1])
coef = lassocv.coef_
lassocv.alpha_

draw_prediction(predictions, y_test, mName)

## lassocv = LassoCV(random_state=0, eps=1e-9, cv=10, n_alphas=100)
#lassocv = LassoLarsCV()
#lassocv.fit(X_train, y_train)
#y_train_pred = lassocv.predict(X_train)
#predictions = lassocv.predict(X_test)
#np.mean(abs(y_train_pred - y_train))/np.mean(y_train)
#np.mean(abs(predictions - y_test))/np.mean(y_test)
#lassocv.coef_
#lassocv.alpha_
#plt.plot_date(t, predictions,'-', label='lassocv')
#plt.legend(loc='upper right')

#%% Ridge regression
mName = 'Ridge'
lassocv = RidgeCV()
lassocv.fit(X_train, y_train)
coef = lassocv.coef_

y_train_pred = lassocv.predict(X_train)
predictions = lassocv.predict(X_test)
predictions = predictions * sY + mY
#predAll = np.append(predAll,predictions.reshape([-1,1]), axis=1)

coef = lassocv.coef_
lassocv.alpha_

draw_prediction(predictions, y_test, mName)

# ax.plot_date(t_test, predictions,'-', label=mName)
# ax.legend(loc='best')
# res = predictions - y_test
# ax2.plot_date(t_test, res, '-', label=mName)
# ax2.legend(loc='best')
# np.mean(abs(y_train_pred - y_train))/np.mean(y_train)
# np.mean(abs(predictions - y_test))/np.mean(y_test)

#%% Random Forest
X = realX
y = realY
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = False)
y_train = ( y_train - mY ) / sY
mName = 'Random Forest'
regr = RandomForestRegressor(random_state=1337)
regr.fit(X_train, y_train)



temp = regr.feature_importances_
temp.sort()
coef = regr.feature_importances_
#coef = np.append(coef,0)

if featSelect == 1:
    
    X = X[:,coef>=temp[-3]]
    y = realY
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = False)
    coef = np.append(coef,0)
    y_train = ( y_train - mY ) / sY
    
    
    selectedFeature = pd.DataFrame(data=coef[coef>=temp[-3]], index=finalDataDf.columns[coef>=temp[-3]], columns=['coef'])
    selectedFeature.sort_values(by=['coef'],ascending=0).to_csv("featureCoef.csv")
    regr = RandomForestRegressor(random_state=1337)
    regr.fit(X_train, y_train)


y_train_pred = regr.predict(X_train)
predictions = regr.predict(X_test)
predictions = predictions * sY + mY
#predAll = np.append(predAll,predictions.reshape([-1,1]), axis=1)

draw_prediction(predictions, y_test, mName)

# ax.plot_date(t_test, predictions, '-', label=mName)
# ax.legend(loc='best')

# res = predictions - y_test
# ax2.plot_date(t_test, res, '-', label=mName)
# ax2.legend(loc='best')
# np.mean(abs(y_train_pred - y_train))/np.mean(y_train)
# np.mean(abs(predictions - y_test))/np.mean(y_test)

#%% XGBoost
X = realX
y = realY
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = False)
y_train = ( y_train - mY ) / sY
mName = 'XGBoost'
xgb = xgboost.XGBRegressor(seed=1337)
xgb.fit(X_train, y_train, verbose=True)

temp = xgb.feature_importances_
temp.sort()
coef = xgb.feature_importances_

if featSelect == 1:

    X = X[:,coef>=temp[-3]]
    y = realY
    coef = np.append(coef,0)
    selectedFeature = pd.DataFrame(data=coef[coef>=temp[-3]], index=finalDataDf.columns[coef>=temp[-3]], columns=['coef'])
    selectedFeature.sort_values(by=['coef'],ascending=0).to_csv("featureCoef.csv")

    
    # 4 feature selected rather than 3
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = False)
    
    y_train = ( y_train - mY ) / sY
    
    xgb = xgboost.XGBRegressor()
    xgb.fit(X_train, y_train)


y_train_pred = xgb.predict(X_train)
predictions = xgb.predict(X_test)
predictions = predictions * sY + mY
#predAll = np.append(predAll,predictions.reshape([-1,1]), axis=1)

draw_prediction(predictions, y_test, mName)

#%% y normalization

#mY = y_train.mean()
#sY = y_train.std()
#y_train = ( y_train - mY ) / sY
#y_test = ( y_test - mY ) / sY

#%% NN
mName = 'NN'
val_loss = []
model_rec = []
history_rec = []

for i in range(10):
    model = Sequential()
    
    model.add(Dense(units=3, activation='relu', input_dim=X.shape[1]))
    #model.add(Dense(units=3, activation='relu', input_dim=X.shape[1]))
    #model.add(Dense(units=3, activation='relu', input_dim=X.shape[1]))
    #model.add(Dense(units=3, activation='relu', input_dim=X.shape[1]))
    model.add(Dense(units=3, activation='relu'))
    model.add(Dense(units=3, activation='relu'))
    model.add(Dense(units=3, activation='relu'))
    model.add(Dense(units=1))
    model.summary()
    
    model.compile(loss='mse', optimizer='adam', metrics=['mse'])
#    model.save_weights('model.h5')
    
    
    model_rec.append(model)
    
    patience = 200
    es=keras.callbacks.EarlyStopping(monitor='val_loss',
                                     mode='min',
                                     patience=patience)
    history = model.fit(X_train, y_train, epochs=20000, validation_split=0.2, callbacks=[es])
    
    history_rec.append(history)
    val_loss.append(history.history['val_loss'][-1])

   
model = model_rec[val_loss.index(min(val_loss))]
history = history_rec[val_loss.index(min(val_loss))]

#epochs = epoch_rec[val_loss.index(min(val_loss))] - patience
epochs = len(history.epoch) - patience
#model.load_weights('model.h5')
model.fit(X_train, y_train, epochs=epochs)


predictions = model.predict(X_test) * sY + mY
predictions = predictions.reshape(-1)
#predAll = np.append(predAll,predictions.reshape([-1,1]), axis=1)
res = predictions - y_test

draw_prediction(predictions, y_test, mName)
model.save_weights(mName + '.h5')

fig = plt.figure()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()



#%% LSTM
mName = 'LSTM'
val_loss = []
model_rec = []
history_rec = []

X_train = X_train.reshape(-1,1,X.shape[1])
y_train = y_train.reshape(-1,1)
X_test = X_test.reshape(-1,1,X.shape[1])
    

for i in range(10):
        
    model = Sequential()
    model.add(keras.layers.LSTM(units=3, input_shape=(1,X.shape[1]), activation='relu'))
    model.add(Dense(units=3, activation='relu'))
    model.add(Dense(units=3, activation='relu'))
    model.add(Dense(units=1))
    
    model.summary()
    
    model.compile(loss='mse', optimizer='adam', metrics=['mse'])
    
    model.save_weights('model' + str(i) + '.h5')
    model_rec.append(model)

    #model.fit(X_train, y_train,epochs=100)
    
    
    patience = 200
    es=keras.callbacks.EarlyStopping(monitor='val_loss',
                                     mode='min',
                                     patience=patience)
    history = model.fit(X_train, y_train, epochs=20000, validation_split=0.2, callbacks=[es])

    history_rec.append(history)
    val_loss.append(history.history['val_loss'][-1])

model.load_weights('model' + str(val_loss.index(min(val_loss))) + '.h5')
#model = model_rec[val_loss.index(min(val_loss))]
history = history_rec[val_loss.index(min(val_loss))]

epochs = len(history.epoch) - patience
#model.load_weights('model.h5')

model.fit(X_train, y_train, epochs=epochs)
#X_test_comb = X_test
X_test_comb = np.concatenate((X_train, X_test))

predictions = model.predict(X_test_comb) * sY + mY
predictions = predictions.reshape(-1)
predictions = predictions[-len(y_test):]
#predAll = np.append(predAll,predictions.reshape([-1,1]), axis=1)
res = predictions - y_test

draw_prediction(predictions, y_test, mName)
model.save_weights(mName + '.h5')

fig = plt.figure()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
# Out:
# C:\Users\sfdd\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.13.1
# 2.2.4-tf
# Index(['demand-7', 'demand-10', 'demand-12'], dtype='object')
# C:\Users\sfdd\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:4057.674202273634
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:3585.7051954180965
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:2965.899005903222
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:2636.359985469926
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:2987.872203039058
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:2964.7293305796306
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:2661.477528514075
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:2634.6328777222143
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:3950.4667191667572
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:3536.5065425451044
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:2937.691951014804
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:2600.414792704787
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:3586.8288230328026
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:3524.883175029543
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:2658.6794897872533
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:2599.638065165528
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:3511.177810132988
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:3110.7359339211434
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:2999.799403611543
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:2649.521690990784
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:3023.6029672816535
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:2994.1455608347646
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:2678.863747732662
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:2647.8163065302733
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:3410.0025904739186
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:3049.8782535722407
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:2938.9794508518034
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:2602.277174292989
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:3104.4929614661974
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:3044.0829503793393
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:2662.9027299502345
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:2601.649914399501
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:3541.0312833894272
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:3138.7137083504367
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:2965.075928575511
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:2635.6315827566054
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:3100.311736336306
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:3102.2823843603023
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:2633.7830576744195
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:2632.7375665731347
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:3436.267133265937
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:3075.2866465767256
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:2939.870081086346
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:2597.8258627943715
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:3092.0908854395384
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:3066.119284878944
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:2625.247487697189
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:2598.3658796022755
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:3362.7691247250523
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:3012.4728411822616
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:2995.295639974985
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:2648.7231012928537
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:2997.9806067159607
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:2996.5071123020207
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:2652.9591512674106
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:2648.288922495675
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:3319.134247078663
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:2955.6642361217746
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:2940.1997083275023
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:2603.2075669284554
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:2983.5918252221636
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:2956.591359865402
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:2634.547765976825
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:2602.614587292164
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2693      0.171     -1.577      0.115      -0.604       0.065
# ma.L1          0.6923      0.147      4.714      0.000       0.405       0.980
# ma.S.L12      -0.1709      0.055     -3.080      0.002      -0.280      -0.062
# sigma2      1.968e+10    1.1e-12    1.8e+22      0.000    1.97e+10    1.97e+10
# ==============================================================================
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0) - AIC:3460.3903689823615
# ARIMA(0, 0, 1) - AIC:3459.9378168874937
# ARIMA(1, 0, 0) - AIC:3457.2000824738466
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:606: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:607: RuntimeWarning: overflow encountered in exp
#   (1+np.exp(-params))).copy()
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:607: RuntimeWarning: invalid value encountered in true_divide
#   (1+np.exp(-params))).copy()
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:608: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:609: RuntimeWarning: overflow encountered in exp
#   (1+np.exp(-params))).copy()
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:609: RuntimeWarning: invalid value encountered in true_divide
#   (1+np.exp(-params))).copy()
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:650: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:650: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:651: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:651: RuntimeWarning: invalid value encountered in true_divide
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:634: RuntimeWarning: divide by zero encountered in true_divide
#   invarcoefs = -np.log((1-params)/(1+params))
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\sfdd\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.486e+06      2e+04    174.123      0.000    3.45e+06    3.53e+06
# ar.L1.0       -0.2018      0.088     -2.303      0.023      -0.373      -0.030
# ==============================================================================
# 0.02854789248476918
# 0.02852781954564259
# 0.026067819427481775
# 0.02907188698153451
# WARNING:tensorflow:From C:\Users\sfdd\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 3)                 84
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 124
# Trainable params: 124
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\sfdd\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 99 samples, validate on 25 samples
# WARNING:tensorflow:From C:\Users\sfdd\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20000
# 99/99 [==============================] - 1s 6ms/sample - loss: 1.0090 - mean_squared_error: 1.0090 - val_loss: 1.0596 - val_mean_squared_error: 1.0596
# Epoch 2/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 1.0031 - mean_squared_error: 1.0031 - val_loss: 1.0500 - val_mean_squared_error: 1.0500
# Epoch 3/20000
# 99/99 [==============================] - 0s 232us/sample - loss: 0.9981 - mean_squared_error: 0.9981 - val_loss: 1.0427 - val_mean_squared_error: 1.0427
# Epoch 4/20000
# 99/99 [==============================] - 0s 232us/sample - loss: 0.9955 - mean_squared_error: 0.9955 - val_loss: 1.0368 - val_mean_squared_error: 1.0368
# Epoch 5/20000
# 99/99 [==============================] - 0s 262us/sample - loss: 0.9939 - mean_squared_error: 0.9939 - val_loss: 1.0323 - val_mean_squared_error: 1.0323
# Epoch 6/20000
# 99/99 [==============================] - 0s 252us/sample - loss: 0.9933 - mean_squared_error: 0.9933 - val_loss: 1.0303 - val_mean_squared_error: 1.0303
# Epoch 7/20000
# 99/99 [==============================] - 0s 232us/sample - loss: 0.9929 - mean_squared_error: 0.9929 - val_loss: 1.0293 - val_mean_squared_error: 1.0293
# Epoch 8/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.9925 - mean_squared_error: 0.9925 - val_loss: 1.0292 - val_mean_squared_error: 1.0292
# Epoch 9/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.9921 - mean_squared_error: 0.9921 - val_loss: 1.0290 - val_mean_squared_error: 1.0290
# Epoch 10/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.9915 - mean_squared_error: 0.9915 - val_loss: 1.0292 - val_mean_squared_error: 1.0292
# Epoch 11/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.9909 - mean_squared_error: 0.9909 - val_loss: 1.0292 - val_mean_squared_error: 1.0292
# Epoch 12/20000
# 99/99 [==============================] - 0s 222us/sample - loss: 0.9905 - mean_squared_error: 0.9905 - val_loss: 1.0289 - val_mean_squared_error: 1.0289
# Epoch 13/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.9901 - mean_squared_error: 0.9901 - val_loss: 1.0282 - val_mean_squared_error: 1.0282
# Epoch 14/20000
# 99/99 [==============================] - 0s 222us/sample - loss: 0.9899 - mean_squared_error: 0.9899 - val_loss: 1.0276 - val_mean_squared_error: 1.0276
# Epoch 15/20000
# 99/99 [==============================] - 0s 242us/sample - loss: 0.9896 - mean_squared_error: 0.9896 - val_loss: 1.0270 - val_mean_squared_error: 1.0270
# Epoch 16/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.9894 - mean_squared_error: 0.9894 - val_loss: 1.0262 - val_mean_squared_error: 1.0262
# Epoch 17/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9892 - mean_squared_error: 0.9892 - val_loss: 1.0259 - val_mean_squared_error: 1.0259
# Epoch 18/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9887 - mean_squared_error: 0.9887 - val_loss: 1.0258 - val_mean_squared_error: 1.0258
# Epoch 19/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9882 - mean_squared_error: 0.9882 - val_loss: 1.0256 - val_mean_squared_error: 1.0256
# Epoch 20/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9878 - mean_squared_error: 0.9878 - val_loss: 1.0254 - val_mean_squared_error: 1.0254
# Epoch 21/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.9873 - mean_squared_error: 0.9873 - val_loss: 1.0247 - val_mean_squared_error: 1.0247
# Epoch 22/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9868 - mean_squared_error: 0.9868 - val_loss: 1.0239 - val_mean_squared_error: 1.0239
# Epoch 23/20000
# 99/99 [==============================] - 0s 171us/sample - loss: 0.9864 - mean_squared_error: 0.9864 - val_loss: 1.0239 - val_mean_squared_error: 1.0239
# Epoch 24/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9859 - mean_squared_error: 0.9859 - val_loss: 1.0243 - val_mean_squared_error: 1.0243
# Epoch 25/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9853 - mean_squared_error: 0.9853 - val_loss: 1.0244 - val_mean_squared_error: 1.0244
# Epoch 26/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.9847 - mean_squared_error: 0.9847 - val_loss: 1.0239 - val_mean_squared_error: 1.0239
# Epoch 27/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.9842 - mean_squared_error: 0.9842 - val_loss: 1.0232 - val_mean_squared_error: 1.0232
# Epoch 28/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.9837 - mean_squared_error: 0.9837 - val_loss: 1.0227 - val_mean_squared_error: 1.0227
# Epoch 29/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9832 - mean_squared_error: 0.9832 - val_loss: 1.0218 - val_mean_squared_error: 1.0218
# Epoch 30/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.9830 - mean_squared_error: 0.9830 - val_loss: 1.0209 - val_mean_squared_error: 1.0209
# Epoch 31/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9827 - mean_squared_error: 0.9827 - val_loss: 1.0202 - val_mean_squared_error: 1.0202
# Epoch 32/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.9820 - mean_squared_error: 0.9820 - val_loss: 1.0197 - val_mean_squared_error: 1.0197
# Epoch 33/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.9811 - mean_squared_error: 0.9811 - val_loss: 1.0193 - val_mean_squared_error: 1.0193
# Epoch 34/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.9801 - mean_squared_error: 0.9801 - val_loss: 1.0193 - val_mean_squared_error: 1.0193
# Epoch 35/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9778 - mean_squared_error: 0.9778 - val_loss: 1.0188 - val_mean_squared_error: 1.0188
# Epoch 36/20000
# 99/99 [==============================] - 0s 171us/sample - loss: 0.9753 - mean_squared_error: 0.9753 - val_loss: 1.0183 - val_mean_squared_error: 1.0183
# Epoch 37/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.9711 - mean_squared_error: 0.9711 - val_loss: 1.0187 - val_mean_squared_error: 1.0187
# Epoch 38/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.9653 - mean_squared_error: 0.9653 - val_loss: 1.0193 - val_mean_squared_error: 1.0193
# Epoch 39/20000
# 99/99 [==============================] - 0s 171us/sample - loss: 0.9584 - mean_squared_error: 0.9584 - val_loss: 1.0196 - val_mean_squared_error: 1.0196
# Epoch 40/20000
# 99/99 [==============================] - 0s 171us/sample - loss: 0.9511 - mean_squared_error: 0.9511 - val_loss: 1.0201 - val_mean_squared_error: 1.0201
# Epoch 41/20000
# 99/99 [==============================] - 0s 171us/sample - loss: 0.9430 - mean_squared_error: 0.9430 - val_loss: 1.0204 - val_mean_squared_error: 1.0204
# Epoch 42/20000
# 99/99 [==============================] - 0s 171us/sample - loss: 0.9333 - mean_squared_error: 0.9333 - val_loss: 1.0219 - val_mean_squared_error: 1.0219
# Epoch 43/20000
# 99/99 [==============================] - 0s 171us/sample - loss: 0.9242 - mean_squared_error: 0.9242 - val_loss: 1.0222 - val_mean_squared_error: 1.0222
# Epoch 44/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.9126 - mean_squared_error: 0.9126 - val_loss: 1.0229 - val_mean_squared_error: 1.0229
# Epoch 45/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.9001 - mean_squared_error: 0.9001 - val_loss: 1.0219 - val_mean_squared_error: 1.0219
# Epoch 46/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.8863 - mean_squared_error: 0.8863 - val_loss: 1.0216 - val_mean_squared_error: 1.0216
# Epoch 47/20000
# 99/99 [==============================] - 0s 161us/sample - loss: 0.8716 - mean_squared_error: 0.8716 - val_loss: 1.0219 - val_mean_squared_error: 1.0219
# Epoch 48/20000
# 99/99 [==============================] - 0s 171us/sample - loss: 0.8562 - mean_squared_error: 0.8562 - val_loss: 1.0223 - val_mean_squared_error: 1.0223
# Epoch 49/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.8393 - mean_squared_error: 0.8393 - val_loss: 1.0205 - val_mean_squared_error: 1.0205
# Epoch 50/20000
# 99/99 [==============================] - 0s 222us/sample - loss: 0.8217 - mean_squared_error: 0.8217 - val_loss: 1.0179 - val_mean_squared_error: 1.0179
# Epoch 51/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.8043 - mean_squared_error: 0.8043 - val_loss: 1.0133 - val_mean_squared_error: 1.0133
# Epoch 52/20000
# 99/99 [==============================] - 0s 222us/sample - loss: 0.7868 - mean_squared_error: 0.7868 - val_loss: 1.0100 - val_mean_squared_error: 1.0100
# Epoch 53/20000
# 99/99 [==============================] - 0s 262us/sample - loss: 0.7676 - mean_squared_error: 0.7676 - val_loss: 1.0071 - val_mean_squared_error: 1.0071
# Epoch 54/20000
# 99/99 [==============================] - 0s 252us/sample - loss: 0.7484 - mean_squared_error: 0.7484 - val_loss: 1.0030 - val_mean_squared_error: 1.0030
# Epoch 55/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.7263 - mean_squared_error: 0.7263 - val_loss: 0.9967 - val_mean_squared_error: 0.9967
# Epoch 56/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.7102 - mean_squared_error: 0.7102 - val_loss: 0.9891 - val_mean_squared_error: 0.9891
# Epoch 57/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.6920 - mean_squared_error: 0.6920 - val_loss: 0.9814 - val_mean_squared_error: 0.9814
# Epoch 58/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.6730 - mean_squared_error: 0.6730 - val_loss: 0.9748 - val_mean_squared_error: 0.9748
# Epoch 59/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.6585 - mean_squared_error: 0.6585 - val_loss: 0.9688 - val_mean_squared_error: 0.9688
# Epoch 60/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.6429 - mean_squared_error: 0.6429 - val_loss: 0.9591 - val_mean_squared_error: 0.9591
# Epoch 61/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.6283 - mean_squared_error: 0.6283 - val_loss: 0.9485 - val_mean_squared_error: 0.9485
# Epoch 62/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.6142 - mean_squared_error: 0.6142 - val_loss: 0.9391 - val_mean_squared_error: 0.9391
# Epoch 63/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.6028 - mean_squared_error: 0.6028 - val_loss: 0.9287 - val_mean_squared_error: 0.9287
# Epoch 64/20000
# 99/99 [==============================] - 0s 202us/sample - loss: 0.5895 - mean_squared_error: 0.5895 - val_loss: 0.9183 - val_mean_squared_error: 0.9183
# Epoch 65/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.5790 - mean_squared_error: 0.5790 - val_loss: 0.9063 - val_mean_squared_error: 0.9063
# Epoch 66/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0
20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.3430 - mean_squared_error: 0.3430 - val_loss: 0.7089 - val_mean_squared_error: 0.7089
# Epoch 92/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.3398 - mean_squared_error: 0.3398 - val_loss: 0.7140 - val_mean_squared_error: 0.7140
# Epoch 93/20000
# 99/99 [==============================] - 0s 222us/sample - loss: 0.3385 - mean_squared_error: 0.3385 - val_loss: 0.7193 - val_mean_squared_error: 0.7193
# Epoch 94/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.3345 - mean_squared_error: 0.3345 - val_loss: 0.7233 - val_mean_squared_error: 0.7233
# Epoch 95/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.3317 - mean_squared_error: 0.3317 - val_loss: 0.7304 - val_mean_squared_error: 0.7304
# Epoch 96/20000
# 99/99 [==============================] - 0s 232us/sample - loss: 0.3276 - mean_squared_error: 0.3276 - val_loss: 0.7394 - val_mean_squared_error: 0.7394
# Epoch 97/20000
# 99/99 [==============================] - 0s 222us/sample - loss: 0.3222 - mean_squared_error: 0.3222 - val_loss: 0.7431 - val_mean_squared_error: 0.7431
# Epoch 98/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.3186 - mean_squared_error: 0.3186 - val_loss: 0.7453 - val_mean_squared_error: 0.7453
# Epoch 99/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.3167 - mean_squared_error: 0.3167 - val_loss: 0.7449 - val_mean_squared_error: 0.7449
# Epoch 100/20000
# 99/99 [==============================] - 0s 222us/sample - loss: 0.3147 - mean_squared_error: 0.3147 - val_loss: 0.7442 - val_mean_squared_error: 0.7442
# Epoch 101/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.3145 - mean_squared_error: 0.3145 - val_loss: 0.7461 - val_mean_squared_error: 0.7461
# Epoch 102/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.3139 - mean_squared_error: 0.3139 - val_loss: 0.7545 - val_mean_squared_error: 0.7545
# Epoch 103/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.3115 - mean_squared_error: 0.3115 - val_loss: 0.7632 - val_mean_squared_error: 0.7632
# Epoch 104/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.3090 - mean_squared_error: 0.3090 - val_loss: 0.7692 - val_mean_squared_error: 0.7692
# Epoch 105/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.3044 - mean_squared_error: 0.3044 - val_loss: 0.7690 - val_mean_squared_error: 0.7690
# Epoch 106/20000
# 99/99 [==============================] - 0s 171us/sample - loss: 0.3012 - mean_squared_error: 0.3012 - val_loss: 0.7584 - val_mean_squared_error: 0.7584
# Epoch 107/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2989 - mean_squared_error: 0.2989 - val_loss: 0.7474 - val_mean_squared_error: 0.7474
# Epoch 108/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.2962 - mean_squared_error: 0.2962 - val_loss: 0.7475 - val_mean_squared_error: 0.7475
# Epoch 109/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2941 - mean_squared_error: 0.2941 - val_loss: 0.7356 - val_mean_squared_error: 0.7356
# Epoch 110/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2934 - mean_squared_error: 0.2934 - val_loss: 0.7230 - val_mean_squared_error: 0.7230
# Epoch 111/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2927 - mean_squared_error: 0.2927 - val_loss: 0.7212 - val_mean_squared_error: 0.7212
# Epoch 112/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.2919 - mean_squared_error: 0.2919 - val_loss: 0.7315 - val_mean_squared_error: 0.7315
# Epoch 113/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.2897 - mean_squared_error: 0.2897 - val_loss: 0.7419 - val_mean_squared_error: 0.7419
# Epoch 114/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2862 - mean_squared_error: 0.2862 - val_loss: 0.7435 - val_mean_squared_error: 0.7435
# Epoch 115/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2834 - mean_squared_error: 0.2834 - val_loss: 0.7356 - val_mean_squared_error: 0.7356
# Epoch 116/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2814 - mean_squared_error: 0.2814 - val_loss: 0.7226 - val_mean_squared_error: 0.7226
# Epoch 117/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.2802 - mean_squared_error: 0.2802 - val_loss: 0.7201 - val_mean_squared_error: 0.7201
# Epoch 118/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.2785 - mean_squared_error: 0.2785 - val_loss: 0.7186 - val_mean_squared_error: 0.7186
# Epoch 119/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.2770 - mean_squared_error: 0.2770 - val_loss: 0.7182 - val_mean_squared_error: 0.7182
# Epoch 120/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2759 - mean_squared_error: 0.2759 - val_loss: 0.7213 - val_mean_squared_error: 0.7213
# Epoch 121/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2740 - mean_squared_error: 0.2740 - val_loss: 0.7262 - val_mean_squared_error: 0.7262
# Epoch 122/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2737 - mean_squared_error: 0.2737 - val_loss: 0.7265 - val_mean_squared_error: 0.7265
# Epoch 123/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2733 - mean_squared_error: 0.2733 - val_loss: 0.7335 - val_mean_squared_error: 0.7335
# Epoch 124/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.2727 - mean_squared_error: 0.2727 - val_loss: 0.7386 - val_mean_squared_error: 0.7386
# Epoch 125/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2714 - mean_squared_error: 0.2714 - val_loss: 0.7405 - val_mean_squared_error: 0.7405
# Epoch 126/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.2696 - mean_squared_error: 0.2696 - val_loss: 0.7402 - val_mean_squared_error: 0.7402
# Epoch 127/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.2682 - mean_squared_error: 0.2682 - val_loss: 0.7417 - val_mean_squared_error: 0.7417
# Epoch 128/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.2655 - mean_squared_error: 0.2655 - val_loss: 0.7395 - val_mean_squared_error: 0.7395
# Epoch 129/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.2642 - mean_squared_error: 0.2642 - val_loss: 0.7402 - val_mean_squared_error: 0.7402
# Epoch 130/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.2627 - mean_squared_error: 0.2627 - val_loss: 0.7466 - val_mean_squared_error: 0.7466
# Epoch 131/20000
# 99/99 [==============================] - 0s 192us/sample - loss: 0.2610 - mean_squared_error: 0.2610 - val_loss: 0.7521 - val_mean_squared_error: 0.7521
# Epoch 132/20000
# 99/99 [==============================] - 0s 212us/sample - loss: 0.2602 - mean_squared_error: 0.2602 - val_loss: 0.7547 - val_mean_squared_error: 0.7547
# Epoch 133/20000
# 99/99 [==============================] - 0s 202us/sample - loss: 0.2588 - mean_squared_error: 0.2588 - val_loss: 0.7634 - val_mean_squared_error: 0.7634
# Epoch 134/20000
# 99/99 [==============================] - 0s 181us/sample - loss: 0.2578 - mean_squared_error: 0.2578 - val_loss: 0.7897 - val_mean_squared_error: 0.7897
# Epoch 135/20000
# 99/99 [==============================] - 0s 222us/sample - loss: 0.2571 - mean_squared_error: 0.2571 - val_loss: 0.8152 - val_mean_squared_error: 0.8152
# Epoch 136/20000
# 99/99 [==============================] - 0s 191us/sample - loss: 0.2565 - mean_squared_error: 0.2565 - val_loss: 0.8319 - val_mean_squared_error: 0.8319
# Epoch 137/20000
# 99/99 [==============================] - 0s 201us/sample - loss: 0.2554 - mean_squared_error: 0.2554 - val_loss: 0.8360 - val_mean_squared_error: 0.8360
# Epoch 138/20000
# ...
# Epoch 286/421
# 124/124 [==============================] - 0s 273us/sample - loss: 0.1551 - mean_squared_error: 0.1551
# Epoch 287/421
# 124/124 [==============================] - 0s 249us/sample - loss: 0.1545 - mean_squared_error: 0.1545
# Epoch 288/421
# 124/124 [==============================] - 0s 241us/sample - loss: 0.1542 - mean_squared_error: 0.1542
# Epoch 289/421
# 124/124 [==============================] - 0s 273us/sample - loss: 0.1538 - mean_squared_error: 0.1538
# Epoch 290/421
# 124/124 [==============================] - 0s 257us/sample - loss: 0.1533 - mean_squared_error: 0.1533
# Epoch 291/421
# 124/124 [==============================] - 0s 257us/sample - loss: 0.1528 - mean_squared_error: 0.1528
# Epoch 292/421
# 124/124 [==============================] - 0s 282us/sample - loss: 0.1525 - mean_squared_error: 0.1525
# Epoch 293/421
# 124/124 [==============================] - 0s 290us/sample - loss: 0.